# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = 'descriptors_labeled_020.csv'
#df = pd.read_excel(file_path)
df = pd.read_csv(file_path)

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['AV', 'SiOSi_std', 'SiOSi_min', 'g_dft', 'SiO_gmean', 'SiOSi_gmean', 'SiOSi_skew', 'k_dft', 'SiOSi_average', 'spg', 'SiOSi_hmean', 'largest_included_sphere', 'SiOSi_var', 'mode_dim', 'SiO_var', 'SiOSi_max', 'NASA', 'VolFrac', 'volume', 'SiO_mean', 'NAV', 'max_dim', 'SiO_min', 'SiO_skew', 'ASA', 'largest_included_sphere_free', 'SiOSi_mean', 'SiO_average', 'density', 'min_dim', 'SiO_max', 'largest_free_sphere', 'SiO_std', 'SiO_hmean']

# %%
print(df.head())
# Out:
#     AV  SiOSi_std   SiOSi_min      g_dft  SiO_gmean  SiOSi_gmean  SiOSi_skew  \
# 0  0.0  13.676657  127.847959  19.469741   1.613342   142.108793    1.111941
# 1  0.0  13.529420  126.848568  25.678167   1.613135   146.696281    0.259465
# 2  0.0  13.147061  133.649003  31.666667   1.612793   150.517855    0.909875
# 3  0.0  11.911599  118.479144  42.213654   1.614886   141.339383   -0.028092
# 4  0.0  12.762654  125.471537  33.721479   1.605952   145.183982   -0.129102
#
#        k_dft  SiOSi_average  spg  ...  ASA  largest_included_sphere_free  \
# 0  35.603627     142.724626    1  ...  0.0                       2.75692
# 1  28.845496     147.311403    2  ...  0.0                       3.23052
# 2  38.549020     151.064456    2  ...  0.0                       3.30432
# 3  43.492960     141.843713    2  ...  0.0                       2.80014
# 4  39.427216     145.749964    2  ...  0.0                       1.91928
#
#    SiOSi_mean  SiO_average   density  min_dim   SiO_max  largest_free_sphere  \
# 0  142.724626     1.613378  2.362780        0  1.634728              1.82941
# 1  147.311403     1.613165  2.261618        0  1.633230              1.79360
# 2  151.064456     1.612830  2.090531        0  1.644048              2.19733
# 3  141.843713     1.614957  2.436450        0  1.636247              1.35004
# 4  145.749964     1.606010  2.494052        0  1.635631              0.79084
#
#     SiO_std  SiO_hmean
# 0  0.010743   1.613307
# 1  0.009763   1.613106
# 2  0.011066   1.612755
# 3  0.015068   1.614816
# 4  0.013751   1.605894
#
# [5 rows x 34 columns]

# %%
print(df.describe())
# Out:
#                AV     SiOSi_std   SiOSi_min       g_dft   SiO_gmean  \
# count  871.000000  8.710000e+02  871.000000  871.000000  871.000000
# mean     0.039214  1.186506e+01  136.115515   27.384339    1.612096
# std      0.064699  4.161903e+00   12.354682    9.945631    0.013549
# min      0.000000  2.900000e-14   90.317587    0.588116    1.587524
# 25%      0.000000  9.546211e+00  127.556898   21.234547    1.605786
# 50%      0.010816  1.177714e+01  135.403523   26.419719    1.610205
# 75%      0.049780  1.376478e+01  145.662103   32.431026    1.614859
# max      0.640644  2.787631e+01  179.479068  125.967578    1.745769
#
#        SiOSi_gmean  SiOSi_skew       k_dft  SiOSi_average         spg  ...  \
# count   871.000000  871.000000  871.000000     871.000000  871.000000  ...
# mean    154.759403    0.042474   45.807335     155.282467   78.483352  ...
# std       7.808180    0.809465   18.796084       7.694336   65.278973  ...
# min     129.359559   -2.409214    3.744544     130.691499    1.000000  ...
# 25%     149.241407   -0.437384   32.486751     149.853198   13.500000  ...
# 50%     155.161439    0.066104   42.917166     155.494003   62.000000  ...
# 75%     159.856467    0.544598   56.132338     160.393046  140.000000  ...
# max     179.479068    3.930465  129.144406     179.479068  230.000000  ...
#
#                ASA  largest_included_sphere_free  SiOSi_mean  SiO_average  \
# count   871.000000                    871.000000  871.000000   871.000000
# mean    159.662912                      5.459604  155.282467     1.612175
# std     287.246964                      3.247147    7.694336     0.013726
# min       0.000000                      0.443230  130.691499     1.587899
# 25%       0.000000                      3.413815  149.853198     1.605832
# 50%       0.000000                      4.446630  155.494003     1.610248
# 75%     274.686500                      6.306850  160.393046     1.614954
# max    2602.240000                     21.126500  179.479068     1.746334
#
#           density     min_dim     SiO_max  largest_free_sphere       SiO_std  \
# count  871.000000  871.000000  871.000000           871.000000  8.710000e+02
# mean     1.870342    0.887486    1.630141             3.962438  1.094236e-02
# std      0.387419    0.943808    0.033510             3.353341  1.203400e-02
# min      0.734265    0.000000    1.598789             0.000000  1.010000e-16
# 25%      1.611027    0.000000    1.617365             2.082415  4.998720e-03
# 50%      1.816107    1.000000    1.624680             3.040520  9.001854e-03
# 75%      2.006850    1.000000    1.632961             4.093595  1.310804e-02
# max      4.071994    3.000000    1.942662            21.006210  1.237348e-01
#
#         SiO_hmean
# count  871.000000
# mean     1.612018
# std      0.013378
# min      1.587150
# 25%      1.605741
# 50%      1.610117
# 75%      1.614811
# max      1.745527
#
# [8 rows x 34 columns]

# %%
print(df.dtypes)
# Out:
# AV                              float64
# SiOSi_std                       float64
# SiOSi_min                       float64
# g_dft                           float64
# SiO_gmean                       float64
# SiOSi_gmean                     float64
# SiOSi_skew                      float64
# k_dft                           float64
# SiOSi_average                   float64
# spg                               int64
# SiOSi_hmean                     float64
# largest_included_sphere         float64
# SiOSi_var                       float64
# mode_dim                          int64
# SiO_var                         float64
# SiOSi_max                       float64
# NASA                            float64
# VolFrac                         float64
# volume                          float64
# SiO_mean                        float64
# NAV                             float64
# max_dim                           int64
# SiO_min                         float64
# SiO_skew                        float64
# ASA                             float64
# largest_included_sphere_free    float64
# SiOSi_mean                      float64
# SiO_average                     float64
# density                         float64
# min_dim                           int64
# SiO_max                         float64
# largest_free_sphere             float64
# SiO_std                         float64
# SiO_hmean                       float64
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# AV                              0
# SiOSi_std                       0
# SiOSi_min                       0
# g_dft                           0
# SiO_gmean                       0
# SiOSi_gmean                     0
# SiOSi_skew                      0
# k_dft                           0
# SiOSi_average                   0
# spg                             0
# SiOSi_hmean                     0
# largest_included_sphere         0
# SiOSi_var                       0
# mode_dim                        0
# SiO_var                         0
# SiOSi_max                       0
# NASA                            0
# VolFrac                         0
# volume                          0
# SiO_mean                        0
# NAV                             0
# max_dim                         0
# SiO_min                         0
# SiO_skew                        0
# ASA                             0
# largest_included_sphere_free    0
# SiOSi_mean                      0
# SiO_average                     0
# density                         0
# min_dim                         0
# SiO_max                         0
# largest_free_sphere             0
# SiO_std                         0
# SiO_hmean                       0
# dtype: int64

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
