# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = 'MyData.xlsx'
df = pd.read_excel(file_path)

# %%
print(df.head())
# Out:
#      type    cell  aperture  aperture2  ExpansionRatio   M-N  Μ-N_lff  \
# 0  CdIF-1  1.8077      3.92     3.9300        1.002551  2.18    2.257
# 1  CdIF-1  1.8077      3.92     3.9900        1.017857  2.18    2.257
# 2  CdIF-1  1.8077      3.92     4.0200        1.025510  2.18    2.257
# 3  CdIF-1  1.8077      3.92     3.9700        1.012755  2.18    2.257
# 4  CdIF-1  1.8077      3.92     4.0415        1.030995  2.18    2.257
#
#    Μ-N_kFF  ionicRad  MetalNum  ...  size - kinetic diameter (Å)  \
# 0  45354.6        92        48  ...                         2.60
# 1  45354.6        92        48  ...                         2.89
# 2  45354.6        92        48  ...                         3.46
# 3  45354.6        92        48  ...                         3.30
# 4  45354.6        92        48  ...                         3.64
#
#     diffusivity  solubility  permeability  Unnamed: 43  Unnamed: 44  \
# 0  6.000000e-08         NaN           NaN          NaN          NaN
# 1  5.000000e-08         NaN           NaN          NaN          NaN
# 2  1.000000e-08         NaN           NaN          NaN          NaN
# 3  4.000000e-09         NaN           NaN          NaN          NaN
# 4  5.000000e-09         NaN           NaN          NaN          NaN
#
#    Unnamed: 45  aperture2.1  Dresults  number of modifications
# 0          NaN       1016.0    1084.0                     72.0
# 1          NaN          NaN       NaN                      NaN
# 2          NaN          NaN       NaN                      NaN
# 3          NaN          NaN       NaN                      NaN
# 4          NaN          NaN       NaN                      NaN
#
# [5 rows x 49 columns]

# %%
print(df.describe())
# Out:
#              cell     aperture    aperture2  ExpansionRatio         M-N  \
# count  573.000000  1275.000000  1017.000000     1275.000000  278.000000
# mean     1.655656     2.917464     3.442865        0.958957    1.941631
# std      0.052681     0.609413     0.395743        0.526431    0.106780
# min      1.539000     1.960000     2.335000        0.000000    1.710000
# 25%      1.622000     2.270000     3.152860        1.005586    1.880000
# 50%      1.653700     2.990000     3.482000        1.054217    1.973000
# 75%      1.699100     3.460000     3.693740        1.248961    1.990000
# max      1.807700     3.920000     4.960000        1.824121    2.180000
#
#            Μ-N_lff       Μ-N_kFF     ionicRad     MetalNum    MetalMass  ...  \
# count  1275.000000   1275.000000  1275.000000  1275.000000  1275.000000  ...
# mean      2.040726  51591.396725    70.587451    25.411765    56.161663  ...
# std       0.134539   7731.980222    13.421526    12.174710    28.377558  ...
# min       1.736000  36233.000000    41.000000     4.000000     9.012000  ...
# 25%       2.034000  45355.000000    71.000000    12.000000    24.305000  ...
# 50%       2.048000  52542.700000    72.000000    29.000000    63.456000  ...
# 75%       2.092000  57111.000000    74.000000    30.000000    65.380000  ...
# max       2.294000  67027.000000    92.000000    48.000000   112.411000  ...
#
#        size - kinetic diameter (Å)   diffusivity  solubility  permeability  \
# count                  1275.000000  1.084000e+03  329.000000  1.110000e+03
# mean                      3.874494  3.050329e-09    2.484710  1.819416e+04
# std                       0.603062  9.687745e-09    6.660132  1.349507e+05
# min                       2.600000  1.460000e-59    0.003160  0.000000e+00
# 25%                       3.460000  2.405000e-17    0.040216  0.000000e+00
# 50%                       3.900000  5.430000e-13    0.199397  0.000000e+00
# 75%                       4.300000  4.410000e-10    1.020010  2.357601e-03
# max                       5.100000  9.000000e-08   55.834048  2.096752e+06
#
#        Unnamed: 43  Unnamed: 44  Unnamed: 45  aperture2.1  Dresults  \
# count          0.0          0.0          0.0          1.0       1.0
# mean           NaN          NaN          NaN       1016.0    1084.0
# std            NaN          NaN          NaN          NaN       NaN
# min            NaN          NaN          NaN       1016.0    1084.0
# 25%            NaN          NaN          NaN       1016.0    1084.0
# 50%            NaN          NaN          NaN       1016.0    1084.0
# 75%            NaN          NaN          NaN       1016.0    1084.0
# max            NaN          NaN          NaN       1016.0    1084.0
#
#        number of modifications
# count                      1.0
# mean                      72.0
# std                        NaN
# min                       72.0
# 25%                       72.0
# 50%                       72.0
# 75%                       72.0
# max                       72.0
#
# [8 rows x 47 columns]

# %%
print(df.dtypes)
# Out:
# type                            object
# cell                           float64
# aperture                       float64
# aperture2                      float64
# ExpansionRatio                 float64
# M-N                            float64
# Μ-N_lff                        float64
# Μ-N_kFF                        float64
# ionicRad                         int64
# MetalNum                         int64
# MetalMass                      float64
# MetalCharge                    float64
# apertureAtom_charge            float64
# σ_1                            float64
# e_1                            float64
# σ_2                            float64
# e_2                            float64
# σ_3                            float64
# e_3                            float64
# linker_length1                 float64
# linker_length2                 float64
# linker_length3                 float64
# linker_mass1                   float64
# linker_mass2                   float64
# linker_mass3                   float64
# func1_length                   float64
# func2_length                   float64
# func3_length                   float64
# func1_mass                     float64
# func2_mass                     float64
# func3_mass                     float64
# func1_charge                   float64
# func2_charge                   float64
# func3_charge                   float64
# gas                             object
# mass                           float64
# Dbulk                          float64
# ascentricF                     float64
# size - van der Waals (Å)       float64
# size - kinetic diameter (Å)    float64
# diffusivity                    float64
# solubility                     float64
# permeability                   float64
# Unnamed: 43                    float64
# Unnamed: 44                    float64
# Unnamed: 45                    float64
# aperture2.1                    float64
# Dresults                       float64
# number of modifications        float64
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# type                              0
# cell                            702
# aperture                          0
# aperture2                       258
# ExpansionRatio                    0
# M-N                             997
# Μ-N_lff                           0
# Μ-N_kFF                           0
# ionicRad                          0
# MetalNum                          0
# MetalMass                         0
# MetalCharge                       0
# apertureAtom_charge            1005
# σ_1                               0
# e_1                               0
# σ_2                               0
# e_2                               0
# σ_3                               0
# e_3                               0
# linker_length1                    0
# linker_length2                    0
# linker_length3                    0
# linker_mass1                      0
# linker_mass2                      0
# linker_mass3                      0
# func1_length                      0
# func2_length                      0
# func3_length                      0
# func1_mass                        0
# func2_mass                        0
# func3_mass                        0
# func1_charge                      0
# func2_charge                      0
# func3_charge                      0
# gas                               0
# mass                              1
# Dbulk                           418
# ascentricF                        0
# size - van der Waals (Å)          0
# size - kinetic diameter (Å)       0
# diffusivity                     191
# solubility                      946
# permeability                    165
# Unnamed: 43                    1275
# Unnamed: 44                    1275
# Unnamed: 45                    1275
# aperture2.1                    1274
# Dresults                       1274
# number of modifications        1274
# dtype: int64

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# C:\Users\John_\AppData\Local\Temp\ipykernel_5576\2176226211.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
